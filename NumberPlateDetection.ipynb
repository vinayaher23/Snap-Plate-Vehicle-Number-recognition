# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import tensorflow as tf
from sklearn.metrics import f1_score 
from tensorflow.keras import optimizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, MaxPooling2D, Dropout, Conv2D
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model

# %%
plate_cascade = cv2.CascadeClassifier('./indian_license_plate.xml')

# %%
# model = keras.models.load_model('path/to/location')

# %%
def detect_plate(img, text=''): # the function detects and perfors blurring on the number plate.
    plate_img = img.copy()
    roi = img.copy()
    plate_rect = plate_cascade.detectMultiScale(plate_img, scaleFactor = 3.2, minNeighbors = 7) # detects numberplates and returns the coordinates and dimensions of detected license plate's contours.
    for (x,y,w,h) in plate_rect:
        roi_ = roi[y:y+h, x:x+w, :] # extracting the Region of Interest of license plate for blurring.
        plate = roi[y:y+h, x:x+w, :]
        cv2.rectangle(plate_img, (x+2,y), (x+w-3, y+h-5), (51,181,155), 3) # finally representing the detected contours by drawing rectangles around the edges.
    if text!='':
        plate_img = cv2.putText(plate_img, text, (x-w//2,y-h//2), 
                                cv2.FONT_HERSHEY_COMPLEX_SMALL , 0.5, (51,181,155), 1, cv2.LINE_AA)
        
    return plate_img, plate # returning the processed image.

# %%
def display(img_, title=''):
    img = cv2.cvtColor(img_, cv2.COLOR_BGR2RGB)
    fig = plt.figure(figsize=(10,6))
    ax = plt.subplot(111)
    ax.imshow(img)
    plt.axis('off')
    plt.title(title)
    plt.show()

img = cv2.imread('./imgs/img10.webp')
display(img, 'input image')

# %%
output_img, plate = detect_plate(img)

# %%
display(output_img, 'detected license plate in the input image')

# %%
display(plate, 'extracted license plate from the image')

# %%
# Match contours to license plate or character template
def find_contours(dimensions, img) :

    # Find all contours in the image
    cntrs, _ = cv2.findContours(img.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    # Retrieve potential dimensions
    lower_width = dimensions[0]
    upper_width = dimensions[1]
    lower_height = dimensions[2]
    upper_height = dimensions[3]
    
    # Check largest 5 or  15 contours for license plate or character respectively
    cntrs = sorted(cntrs, key=cv2.contourArea, reverse=True)[:15]
    
    ii = cv2.imread('contour.jpg')
    
    x_cntr_list = []
    target_contours = []
    img_res = []
    for cntr in cntrs :
        # detects contour in binary image and returns the coordinates of rectangle enclosing it
        intX, intY, intWidth, intHeight = cv2.boundingRect(cntr)
        
        # checking the dimensions of the contour to filter out the characters by contour's size
        if intWidth > lower_width and intWidth < upper_width and intHeight > lower_height and intHeight < upper_height :
            x_cntr_list.append(intX) #stores the x coordinate of the character's contour, to used later for indexing the contours

            char_copy = np.zeros((44,24))
            # extracting each character using the enclosing rectangle's coordinates.
            char = img[intY:intY+intHeight, intX:intX+intWidth]
            char = cv2.resize(char, (20, 40))
            
            cv2.rectangle(ii, (intX,intY), (intWidth+intX, intY+intHeight), (50,21,200), 2)
            plt.imshow(ii, cmap='gray')

            # Make result formatted for classification: invert colors
            char = cv2.subtract(255, char)

            # Resize the image to 24x44 with black border
            char_copy[2:42, 2:22] = char
            char_copy[0:2, :] = 0
            char_copy[:, 0:2] = 0
            char_copy[42:44, :] = 0
            char_copy[:, 22:24] = 0

            img_res.append(char_copy) # List that stores the character's binary image (unsorted)
            
    # Return characters on ascending order with respect to the x-coordinate (most-left character first)
            
    plt.show()
    # arbitrary function that stores sorted list of character indeces
    indices = sorted(range(len(x_cntr_list)), key=lambda k: x_cntr_list[k])
    img_res_copy = []
    for idx in indices:
        img_res_copy.append(img_res[idx])# stores character images according to their index
    img_res = np.array(img_res_copy)

    return img_res

# %%
def segment_characters(image) :

    # Preprocess cropped license plate image
    img_lp = cv2.resize(image, (333, 75))
    img_gray_lp = cv2.cvtColor(img_lp, cv2.COLOR_BGR2GRAY)
    _, img_binary_lp = cv2.threshold(img_gray_lp, 200, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    img_binary_lp = cv2.erode(img_binary_lp, (3,3))
    img_binary_lp = cv2.dilate(img_binary_lp, (3,3))

    LP_WIDTH = img_binary_lp.shape[0]
    LP_HEIGHT = img_binary_lp.shape[1]

    # Make borders white
    img_binary_lp[0:3,:] = 255
    img_binary_lp[:,0:3] = 255
    img_binary_lp[72:75,:] = 255
    img_binary_lp[:,330:333] = 255

    # Estimations of character contours sizes of cropped license plates
    dimensions = [LP_WIDTH/6,
                       LP_WIDTH/2,
                       LP_HEIGHT/10,
                       2*LP_HEIGHT/3]
    plt.imshow(img_binary_lp, cmap='gray')
    plt.show()
    cv2.imwrite('contour.jpg',img_binary_lp)

    # Get contours within cropped license plate
    char_list = find_contours(dimensions, img_binary_lp)

    return char_list

# %%
char = segment_characters(plate)

# %%
lenofnumplate = len(char)
for i in range(lenofnumplate):
    plt.subplot(1, lenofnumplate, i+1)
    plt.imshow(char[i], cmap='gray')
    plt.axis('off')

# %%
import tensorflow.keras.backend as K
train_datagen = ImageDataGenerator(rescale=1./255, width_shift_range=0.1, height_shift_range=0.1)
path = './data/data'
train_generator = train_datagen.flow_from_directory(
        path+'/train',  # this is the target directory
        target_size=(28,28),  # all images will be resized to 28x28
        batch_size=1,
        class_mode='sparse')

validation_generator = train_datagen.flow_from_directory(
        path+'/val',  # this is the target directory
        target_size=(28,28),  # all images will be resized to 28x28 batch_size=1,
        class_mode='sparse')
# Out:
# Found 867 images belonging to 36 classes.
# Found 216 images belonging to 36 classes.

# %%
# Metrics for checking the model performance while training
def f1score(y, y_pred):
  return f1_score(y, tf.math.argmax(y_pred, axis=1), average='micro') 

def accuracy(y, y_pred):
  return tf.py_function(f1score, (y, y_pred), tf.double)

# %%
K.clear_session()
model = Sequential()
model.add(Conv2D(16, (22,22), input_shape=(28, 28, 3), activation='relu', padding='same'))
model.add(Conv2D(32, (16,16), input_shape=(28, 28, 3), activation='relu', padding='same'))
model.add(Conv2D(64, (8,8), input_shape=(28, 28, 3), activation='relu', padding='same'))
model.add(Conv2D(64, (4,4), input_shape=(28, 28, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(4, 4)))
model.add(Dropout(0.4))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(36, activation='softmax'))

#     model.compile(loss='binary_crossentropy',loss_weights={'class':0.5}, optimizer='adam', metrics=['accuracy'])

model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizers.Adam(learning_rate=0.0001), metrics=[accuracy])
# model.compile(loss='sparse_categorical_crossentropy', metrics=[custom_f1score])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 16)        23248
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        131104
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 64)        131136
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 64)        65600
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 7, 7, 64)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               401536
# _________________________________________________________________
# dense_1 (Dense)              (None, 36)                4644
# =================================================================
# Total params: 757,268
# Trainable params: 757,268
# Non-trainable params: 0
# _________________________________________________________________

# %%
class stop_training_callback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('val_custom_f1score') > 0.99):
      self.model.stop_training = True

# %%
batch_size = 1
callbacks = [stop_training_callback()]
his = model.fit(
      train_generator,
      steps_per_epoch = train_generator.samples // batch_size,
      validation_data = validation_generator, 
      epochs = 80, verbose=1)
#     model.fit(
#       train_generator,
#       steps_per_epoch = train_generator.samples // batch_size,
#       validation_data = validation_generator, 
#       epochs = 15, verbose=1#, callbacks=callbacks)
# Out:
# Epoch 1/80
# 863/863 [==============================] - 52s 56ms/step - loss: 3.0394 - accuracy: 0.1808 - val_loss: 1.9631 - val_accuracy: 0.4435
# Epoch 2/80
# 863/863 [==============================] - 56s 65ms/step - loss: 1.4484 - accuracy: 0.5666 - val_loss: 1.0800 - val_accuracy: 0.6622
# Epoch 3/80
# 863/863 [==============================] - 57s 66ms/step - loss: 0.8438 - accuracy: 0.7358 - val_loss: 0.4926 - val_accuracy: 0.8542
# Epoch 4/80
# 863/863 [==============================] - 57s 66ms/step - loss: 0.4700 - accuracy: 0.8355 - val_loss: 0.4579 - val_accuracy: 0.8601
# Epoch 5/80
# 863/863 [==============================] - 58s 67ms/step - loss: 0.4054 - accuracy: 0.8621 - val_loss: 0.3279 - val_accuracy: 0.9062
# Epoch 6/80
# 863/863 [==============================] - 65s 75ms/step - loss: 0.2985 - accuracy: 0.9061 - val_loss: 0.2430 - val_accuracy: 0.9196
# Epoch 7/80
# 863/863 [==============================] - 67s 77ms/step - loss: 0.2910 - accuracy: 0.9038 - val_loss: 0.2054 - val_accuracy: 0.9286
# Epoch 8/80
# 863/863 [==============================] - 65s 75ms/step - loss: 0.2068 - accuracy: 0.9328 - val_loss: 0.1398 - val_accuracy: 0.9494
# Epoch 9/80
# 863/863 [==============================] - 65s 75ms/step - loss: 0.1808 - accuracy: 0.9421 - val_loss: 0.1812 - val_accuracy: 0.9330
# Epoch 10/80
# 863/863 [==============================] - 61s 71ms/step - loss: 0.1708 - accuracy: 0.9490 - val_loss: 0.1136 - val_accuracy: 0.9732
# Epoch 11/80
# 863/863 [==============================] - 59s 69ms/step - loss: 0.1519 - accuracy: 0.9455 - val_loss: 0.1219 - val_accuracy: 0.9524
# Epoch 12/80
# 863/863 [==============================] - 60s 69ms/step - loss: 0.1869 - accuracy: 0.9397 - val_loss: 0.1759 - val_accuracy: 0.9330
# Epoch 13/80
# 863/863 [==============================] - 58s 67ms/step - loss: 0.1345 - accuracy: 0.9560 - val_loss: 0.2165 - val_accuracy: 0.9360
# Epoch 14/80
# 863/863 [==============================] - 58s 68ms/step - loss: 0.1047 - accuracy: 0.9652 - val_loss: 0.1872 - val_accuracy: 0.9435
# Epoch 15/80
# 863/863 [==============================] - 59s 68ms/step - loss: 0.1202 - accuracy: 0.9606 - val_loss: 0.0813 - val_accuracy: 0.9732
# Epoch 16/80
# 863/863 [==============================] - 59s 68ms/step - loss: 0.1193 - accuracy: 0.9618 - val_loss: 0.0555 - val_accuracy: 0.9747
# Epoch 17/80
# 863/863 [==============================] - 59s 68ms/step - loss: 0.1069 - accuracy: 0.9618 - val_loss: 0.1782 - val_accuracy: 0.9539
# Epoch 18/80
# 863/863 [==============================] - 59s 68ms/step - loss: 0.0889 - accuracy: 0.9722 - val_loss: 0.0438 - val_accuracy: 0.9911
# Epoch 19/80
# 863/863 [==============================] - 59s 68ms/step - loss: 0.0818 - accuracy: 0.9687 - val_loss: 0.1092 - val_accuracy: 0.9479
# Epoch 20/80
# 863/863 [==============================] - 59s 68ms/step - loss: 0.1091 - accuracy: 0.9629 - val_loss: 0.0432 - val_accuracy: 0.9911
# Epoch 21/80
# 863/863 [==============================] - 61s 70ms/step - loss: 0.1097 - accuracy: 0.9548 - val_loss: 0.1312 - val_accuracy: 0.9345
# Epoch 22/80
# 863/863 [==============================] - 61s 70ms/step - loss: 0.1333 - accuracy: 0.9618 - val_loss: 0.0358 - val_accuracy: 0.9821
# Epoch 23/80
# 863/863 [==============================] - 62s 72ms/step - loss: 0.0350 - accuracy: 0.9838 - val_loss: 0.0783 - val_accuracy: 0.9807
# Epoch 24/80
# 863/863 [==============================] - 63s 73ms/step - loss: 0.0494 - accuracy: 0.9849 - val_loss: 0.0267 - val_accuracy: 1.0000
# Epoch 25/80
# 863/863 [==============================] - 60s 69ms/step - loss: 0.0896 - accuracy: 0.9745 - val_loss: 0.0957 - val_accuracy: 0.9613
# Epoch 26/80
# 863/863 [==============================] - 59s 68ms/step - loss: 0.1217 - accuracy: 0.9571 - val_loss: 0.0696 - val_accuracy: 0.9643
# Epoch 27/80
# 863/863 [==============================] - 60s 69ms/step - loss: 0.0762 - accuracy: 0.9710 - val_loss: 0.0289 - val_accuracy: 0.9911
# Epoch 28/80
# 863/863 [==============================] - 60s 69ms/step - loss: 0.0619 - accuracy: 0.9768 - val_loss: 0.0278 - val_accuracy: 0.9866
# Epoch 29/80
# 863/863 [==============================] - 60s 69ms/step - loss: 0.0405 - accuracy: 0.9873 - val_loss: 0.0344 - val_accuracy: 0.9866
# Epoch 30/80
# 863/863 [==============================] - 60s 69ms/step - loss: 0.0435 - accuracy: 0.9745 - val_loss: 0.0380 - val_accuracy: 0.9807
# Epoch 31/80
# 863/863 [==============================] - 59s 69ms/step - loss: 0.1319 - accuracy: 0.9629 - val_loss: 0.0292 - val_accuracy: 0.9955
# Epoch 32/80
# 863/863 [==============================] - 59s 68ms/step - loss: 0.0750 - accuracy: 0.9722 - val_loss: 0.0550 - val_accuracy: 0.9747
# Epoch 33/80
# 863/863 [==============================] - 58s 68ms/step - loss: 0.0465 - accuracy: 0.9838 - val_loss: 0.1210 - val_accuracy: 0.9762
# Epoch 34/80
# 863/863 [==============================] - 59s 68ms/step - loss: 0.0409 - accuracy: 0.9826 - val_loss: 0.0755 - val_accuracy: 0.9807
# Epoch 35/80
# 863/863 [==============================] - 61s 70ms/step - loss: 0.0748 - accuracy: 0.9803 - val_loss: 0.0379 - val_accuracy: 0.9851
# Epoch 36/80
# 863/863 [==============================] - 59s 69ms/step - loss: 0.0478 - accuracy: 0.9768 - val_loss: 0.0410 - val_accuracy: 0.9807
# Epoch 37/80
# 863/863 [==============================] - 59s 68ms/step - loss: 0.0262 - accuracy: 0.9826 - val_loss: 0.0302 - val_accuracy: 0.9911
# Epoch 38/80
# 863/863 [==============================] - 59s 69ms/step - loss: 0.0456 - accuracy: 0.9826 - val_loss: 0.0451 - val_accuracy: 0.9807
# Epoch 39/80
# 863/863 [==============================] - 59s 68ms/step - loss: 0.0710 - accuracy: 0.9722 - val_loss: 0.1084 - val_accuracy: 0.9673
# Epoch 40/80
# 863/863 [==============================] - 60s 69ms/step - loss: 0.0995 - accuracy: 0.9687 - val_loss: 0.0357 - val_accuracy: 0.9896
# Epoch 41/80
# 863/863 [==============================] - 60s 69ms/step - loss: 0.0410 - accuracy: 0.9815 - val_loss: 0.1330 - val_accuracy: 0.9688
# Epoch 42/80
# 863/863 [==============================] - 59s 69ms/step - loss: 0.0437 - accuracy: 0.9849 - val_loss: 0.0320 - val_accuracy: 0.9866
# Epoch 43/80
# 863/863 [==============================] - 59s 69ms/step - loss: 0.0943 - accuracy: 0.9652 - val_loss: 0.0909 - val_accuracy: 0.9673
# Epoch 44/80
# 863/863 [==============================] - 60s 69ms/step - loss: 0.0488 - accuracy: 0.9803 - val_loss: 0.0260 - val_accuracy: 0.9896
# Epoch 45/80
# 863/863 [==============================] - 59s 68ms/step - loss: 0.0648 - accuracy: 0.9791 - val_loss: 0.0502 - val_accuracy: 0.9807
# Epoch 46/80
# 863/863 [==============================] - 59s 68ms/step - loss: 0.0367 - accuracy: 0.9826 - val_loss: 0.0736 - val_accuracy: 0.9821
# Epoch 47/80
# 863/863 [==============================] - 59s 68ms/step - loss: 0.0644 - accuracy: 0.9780 - val_loss: 0.0300 - val_accuracy: 0.9911
# Epoch 48/80
# 863/863 [==============================] - 59s 68ms/step - loss: 0.0462 - accuracy: 0.9803 - val_loss: 0.1639 - val_accuracy: 0.9732
# Epoch 49/80
# 863/863 [==============================] - 59s 69ms/step - loss: 0.0525 - accuracy: 0.9803 - val_loss: 0.0305 - val_accuracy: 0.9762
# Epoch 50/80
# 863/863 [==============================] - 60s 69ms/step - loss: 0.0466 - accuracy: 0.9803 - val_loss: 0.0792 - val_accuracy: 0.9717
# Epoch 51/80
# 863/863 [==============================] - 59s 68ms/step - loss: 0.0548 - accuracy: 0.9815 - val_loss: 0.0694 - val_accuracy: 0.9821
# Epoch 52/80
# 863/863 [==============================] - 60s 69ms/step - loss: 0.0446 - accuracy: 0.9803 - val_loss: 0.0807 - val_accuracy: 0.9866
# Epoch 53/80
# 863/863 [==============================] - 60s 70ms/step - loss: 0.0380 - accuracy: 0.9838 - val_loss: 0.1766 - val_accuracy: 0.9598
# Epoch 54/80
# 863/863 [==============================] - 60s 69ms/step - loss: 0.0711 - accuracy: 0.9780 - val_loss: 0.1884 - val_accuracy: 0.9583
# Epoch 55/80
# 863/863 [==============================] - 59s 68ms/step - loss: 0.0384 - accuracy: 0.9838 - val_loss: 0.0489 - val_accuracy: 0.9821
# Epoch 56/80
# 863/863 [==============================] - 60s 69ms/step - loss: 0.0342 - accuracy: 0.9838 - val_loss: 0.0405 - val_accuracy: 0.9807
# Epoch 57/80
# 863/863 [==============================] - 58s 67ms/step - loss: 0.0318 - accuracy: 0.9838 - val_loss: 0.0228 - val_accuracy: 0.9911
# Epoch 58/80
# 863/863 [==============================] - 58s 68ms/step - loss: 0.0521 - accuracy: 0.9838 - val_loss: 0.0593 - val_accuracy: 0.9807
# Epoch 59/80
# 863/863 [==============================] - 58s 67ms/step - loss: 0.1060 - accuracy: 0.9699 - val_loss: 0.0678 - val_accuracy: 0.9673
# Epoch 60/80
# 863/863 [==============================] - 58s 68ms/step - loss: 0.0308 - accuracy: 0.9826 - val_loss: 0.0473 - val_accuracy: 0.9821
# Epoch 61/80
# 863/863 [==============================] - 58s 67ms/step - loss: 0.0225 - accuracy: 0.9907 - val_loss: 0.0935 - val_accuracy: 0.9702
# Epoch 62/80
# 863/863 [==============================] - 58s 67ms/step - loss: 0.1158 - accuracy: 0.9745 - val_loss: 0.0252 - val_accuracy: 0.9851
# Epoch 63/80
# 863/863 [==============================] - 58s 68ms/step - loss: 0.0250 - accuracy: 0.9884 - val_loss: 0.0604 - val_accuracy: 0.9821
# Epoch 64/80
# 863/863 [==============================] - 58s 67ms/step - loss: 0.0396 - accuracy: 0.9838 - val_loss: 0.0420 - val_accuracy: 0.9866
# Epoch 65/80
# 863/863 [==============================] - 58s 67ms/step - loss: 0.0825 - accuracy: 0.9768 - val_loss: 0.0225 - val_accuracy: 0.9866
# Epoch 66/80
# 863/863 [==============================] - 59s 68ms/step - loss: 0.0494 - accuracy: 0.9791 - val_loss: 0.1218 - val_accuracy: 0.9762
# Epoch 67/80
# 863/863 [==============================] - 57s 67ms/step - loss: 0.0576 - accuracy: 0.9873 - val_loss: 0.0345 - val_accuracy: 0.9851
# Epoch 68/80
# 863/863 [==============================] - 59s 68ms/step - loss: 0.0272 - accuracy: 0.9907 - val_loss: 0.0344 - val_accuracy: 0.9762
# Epoch 69/80
# 863/863 [==============================] - 59s 68ms/step - loss: 0.0689 - accuracy: 0.9815 - val_loss: 0.1352 - val_accuracy: 0.9702
# Epoch 70/80
# 863/863 [==============================] - 59s 68ms/step - loss: 0.0325 - accuracy: 0.9907 - val_loss: 0.0148 - val_accuracy: 0.9955
# Epoch 71/80
# 863/863 [==============================] - 60s 69ms/step - loss: 0.0493 - accuracy: 0.9838 - val_loss: 0.1072 - val_accuracy: 0.9821
# Epoch 72/80
# 863/863 [==============================] - 58s 67ms/step - loss: 0.1038 - accuracy: 0.9733 - val_loss: 0.0880 - val_accuracy: 0.9851
# Epoch 73/80
# 863/863 [==============================] - 58s 68ms/step - loss: 0.0198 - accuracy: 0.9907 - val_loss: 0.0565 - val_accuracy: 0.9851
# Epoch 74/80
# 863/863 [==============================] - 58s 68ms/step - loss: 0.0284 - accuracy: 0.9873 - val_loss: 0.0171 - val_accuracy: 0.9955
# Epoch 75/80
# 863/863 [==============================] - 60s 70ms/step - loss: 0.0339 - accuracy: 0.9849 - val_loss: 0.0169 - val_accuracy: 0.9940
# Epoch 76/80
# 863/863 [==============================] - 59s 68ms/step - loss: 0.0292 - accuracy: 0.9873 - val_loss: 0.0198 - val_accuracy: 0.9911
# Epoch 77/80
# 863/863 [==============================] - 59s 68ms/step - loss: 0.0581 - accuracy: 0.9791 - val_loss: 0.0311 - val_accuracy: 0.9911
# Epoch 78/80
# 863/863 [==============================] - 58s 68ms/step - loss: 0.0892 - accuracy: 0.9791 - val_loss: 0.0181 - val_accuracy: 0.9911
# Epoch 79/80
# 863/863 [==============================] - 60s 69ms/step - loss: 0.0562 - accuracy: 0.9849 - val_loss: 0.0128 - val_accuracy: 0.9955
# Epoch 80/80
# 863/863 [==============================] - 62s 71ms/step - loss: 0.0235 - accuracy: 0.9896 - val_loss: 0.1196 - val_accuracy: 0.9583

# %%
# print(his.params)

# %%
model.save('NewModel.h5')

# %%
# from tensorflow.keras.models import Model
# import keras
# from keras.models import load_model
# model.save('gfgModel.h5')
# print('Model Saved!')

# # # load model
# new_model = load_model("NumberPlate.h5")
# filepath = load_model('numberr.h5')

# float_model = load_model(filepath)

# new_model.summary()
# # savedModel=load_model('NumberPlate.h5')
# # print(savedModel)

# %%
new_model = load_model('./NewModel.h5')

new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 16)        23248
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        131104
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 64)        131136
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 64)        65600
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 7, 7, 64)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               401536
# _________________________________________________________________
# dense_1 (Dense)              (None, 36)                4644
# =================================================================
# Total params: 757,268
# Trainable params: 757,268
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Predicting the output

def fix_dimension(img): 
  new_img = np.zeros((28,28,3))
  for i in range(3):
    new_img[:,:,i] = img
  return new_img

  
def show_results():
    dic = {}
    characters = '0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    for i,c in enumerate(characters):
        dic[i] = c
        
    output = []
    
    for i,ch in enumerate(char): #iterating over the characters
        img_ = cv2.resize(ch, (28,28), interpolation=cv2.INTER_AREA)
        img = fix_dimension(img_)
        img = img.reshape(1,28,28,3) #preparing image for the model
#         y_ = model.predict_classes(img)[0] #predicting the class
        y_ = np.argmax(new_model.predict(img)[0], axis=-1)

        character = dic[y_] #
        output.append(character) #storing the result in a list
        
    plate_number = ''.join(output)
    
    return plate_number

print(show_results())
# Out:
# 0C3P2

# %% [raw]
# plt.figure(figsize=(10,6))
# for i,ch in enumerate(char):
#     img = cv2.resize(ch, (28,28), interpolation=cv2.INTER_AREA)
#     plt.subplot(3,4,i+1)
#     plt.imshow(img,cmap='gray')
#     plt.title(f'predicted: {show_results()[i]}')
#     plt.axis('off')
# plt.show()

# %%
plate_number = show_results()
output_img, plate = detect_plate(img, plate_number)
display(output_img, 'detected license plate number in the input image')
